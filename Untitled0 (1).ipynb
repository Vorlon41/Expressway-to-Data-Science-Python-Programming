# %%
print('Hello, C!')
# Out:
# Hello, C!

# %%
print("I'm OK")
# Out:
# I'm OK

# %% [markdown]
# Need to use double quotes if you want to print the single quote

# %%
print('I\'m  OK!')
# Out:
# I'm  OK!

# %% [markdown]
# Need to use an escape mark if you want to use single quotes. The escapte mark is a backspace

# %%
print('This is a new \n line')
# Out:
# This is a new
#  line

# %% [markdown]
# The backslash n will put the following words on a new line

# %% [markdown]
# A baskslash t will create a tab \t
#
# A backslash backslash will insert a backslash \\ will print a \

# %%
print('Hello \t world')
# Out:
# Hello 	 world

# %%
print('Hello \\ world')
# Out:
# Hello \ world

# %%
print('''
This
is
the
first
line''')
# Out:
# This
# is
# the
# first
# line

# %% [markdown]
# Single quotation can only have one line. A triple single quote will print in multiple lines

# %%
print('''
"How are you"?
"I am fine"
''')
# Out:
# "How are you"?
# "I am fine"
