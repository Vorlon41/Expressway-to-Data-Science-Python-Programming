# %%
print(input("What is your name? "))
# Out:
# What is your name? C
# C

# %%
print("Hello, ", input("What is your name? "))
# Out:
# What is your name? C
# Hello,  C

# %% [markdown]
# Lab 2

# %%
print(input("What's your name? "))
# Out:
# What's your name? C
# C

# %%
print(input("How do you feel so far? 1 for Good, 2 for very good "))
# Out:
# How do you feel so far? 1 for Good, 2 for very good 1
# 1

# %%
print(input("Are you ready to learn more? Enter Yes or No: "))

# %%
print(input("How old are you? "))
# Out:
# How old are you? 40
# '40'

# %%
print(input("Which number is your lucky number? "))
# Out:
# Which number is your lucky number? 45
# '45'

# %%
print(input("What date is today? yyyymmdd "))
# Out:
# What date is today? yyyymmdd 20241120
# '20241120'
