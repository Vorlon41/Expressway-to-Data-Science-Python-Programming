# %% [markdown]
# # Module 2 Lab 1

# %% [markdown]
# TaskB assign x with an int 5

# %%
x = 5
print('x:', x, type(x))
# Out:
# x: 5 <class 'int'>

# %% [markdown]
# ### TaskB assign int_x with x

# %%
int_x = x
print('x:', x, type(x))
print('int_x:', int_x, type(int_x))
# Out:
# x: 5 <class 'int'>
# int_x: 5 <class 'int'>

# %% [markdown]
# ### TaskB assign x with a float 5.0

# %%
x = 5.0
print('x:', x, type(x))
# Out:
# x: 5.0 <class 'float'>

# %% [markdown]
# ###TaskB assign float_x with x

# %%
float_x = x
print('x:', x, type(x))
print('float_x:', float_x, type(float_x))
# Out:
# x: 5.0 <class 'float'>
# float_x: 5.0 <class 'float'>

# %% [markdown]
# ###TaskB assign x with a str '5'

# %%
x = '5'
print('x', x, type (x))
# Out:
# x 5 <class 'str'>

# %% [markdown]
# ###TaskB assign str,_x with x

# %%
str1_x = x
print('x', x, type(x))
print('str1_x1', str1_x, type(str1_x))
# Out:
# x 5 <class 'str'>
# str1_x1 5 <class 'str'>

# %% [markdown]
# ###TaskB assign x with a str '5.0'

# %%
x = '5.0'
print('x:', x, type(x))
# Out:
# x: 5.0 <class 'str'>

# %% [markdown]
# ###TaskB assign str-_x with x

# %%
str2_x = x
print('x:', x, type(x))
print('str2_x:', str2_x, type(str2_x))
# Out:
# x: 5.0 <class 'str'>
# str2_x: 5.0 <class 'str'>

# %% [markdown]
# ###TaskB check all variables

# %%
print('x:', x, type(x))
print('int_x:', int_x, type(int_x))
print('float_x:', float_x, type(float_x))
print('str1_x:', str1_x, type(str1_x))
print('str2_x:', str2_x, type(str2_x))
# Out:
# x: 5.0 <class 'str'>
# int_x: 5 <class 'int'>
# float_x: 5.0 <class 'float'>
# str1_x: 5 <class 'str'>
# str2_x: 5.0 <class 'str'>

# %% [markdown]
# ## Value converting

# %% [markdown]
# ### TaskB convert a str '0' to int

# %%
x = int('0')
print('x:', x, type(x))
# Out:
# x: 0 <class 'int'>

# %% [markdown]
# ###TaskB convert a float 0.1 to int

# %%
x = int(0.1)
print('x:', x, type(x))
# Out:
# x: 0 <class 'int'>

# %% [markdown]
# ###TaskB convert a str '0' to float

# %%
x = float('0')
print('x:', x, type(x))
# Out:
# x: 0.0 <class 'float'>

# %% [markdown]
# ###TaskB convert an int 0 to str

# %%
x = str(0)
print('x:', x, type(x))
# Out:
# x: 0 <class 'str'>

# %% [markdown]
# ###TaskB convert a float I6O to str
