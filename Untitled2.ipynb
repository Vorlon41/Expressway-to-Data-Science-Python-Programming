# %% [markdown]
# Module 1 First Assignment

# %% [markdown]
# Prepare a document

# %% [markdown]
# ###Instructions
# You are going to print a document on the screen3
# The document is a templateF which
# has {} as place holder and should get inputs from the user3 Let's get it done step by step3
# You should use multiple input() to get the information from the user3
# The template is as belowE
# Dear {receiver's name}E
# This is {your first name}3 I'm writing to let you know that the weather in {your location} is fantastic!
# I'm taking Python for Data Science course3 I have coded {#} programs and the expereince was fun! Join
# me if you are interested!
# SincerelyF
# {your full name}
# {date}

# %%
print("Dear", input("What is the name of the receiver? "))
# Out:
# What is the name of the receiver? C
# Dear C

# %%
print("This is", input("What is your first name?" ),". I'm writing to let you know that the weather in", input("What is your location " ), "is fantastic")
# Out:
# What is your first name?C
# What is your location T
# This is C . I'm writing to let you know that the weather in T is fantastic

# %%
print("I'm taking Python for Data Science course. I have coded", input("How many programs have you coded? "), "programs and the expereince was fun! Join me if you are interested!")
# Out:
# How many programs have you coded? 5
# I'm taking Python for Data Science course. I have coded 5 programs and the expereince was fun! Join me if you are interested!

# %%
print("Sincerely,")
# Out:
# Sincerely,

# %%
print(input("What is your full name?"))
# Out:
# What is your full name?CJ
# CJ

# %%
print(input("What is today's date?"))
# Out:
# What is today's date?6/5/24
# 6/5/24
